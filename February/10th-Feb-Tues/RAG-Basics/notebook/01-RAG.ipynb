# %% [markdown]
# ### RAG Pipeline - Data Ingestion to VectorDB

# %%
import os
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_transformers import Re
