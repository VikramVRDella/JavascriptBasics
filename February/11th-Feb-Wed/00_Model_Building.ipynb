# %%
import tensorflow as tf

# %%
import numpy as np

x = np.array([[1],
              [2],
              [3],
              [4],
              [5]])

y = np.array([[2],
              [4],
              [6],
              [8],
              [10]])

# %%
X=tf.cast(x,dtype=tf.float32)
Y=tf.cast(y,dtype=tf.float32)

# %%
#Defining the Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# %%
#Compiling the Model
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.SGD(),metrics=["mae"])

# %%
#Fitting the model with the Variable

# %%
model.fit(X,Y,epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - loss: 5.5400 - mae: 5.5400
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 5.4400 - mae: 5.4400
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 5.3400 - mae: 5.3400
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 5.2400 - mae: 5.2400
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 5.1400 - mae: 5.1400

# %%
#Predict using the build model

# %%
y_pred = model.predict(X)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
y_pred
# Out:
# array([[0.3533365 ],
#        [0.6566731 ],
#        [0.96000963],
#        [1.2633461 ],
#        [1.5666826 ]], dtype=float32)

# %%
#Finding the error from the y to y_pred

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp310-cp310-win_amd64.whl (8.1 MB)
#      ---------------------------------------- 8.1/8.1 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.1.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.61.1-cp310-cp310-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 19.7 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
#      ------------------------------------- 221.2/221.2 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (26.0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-win_amd64.whl (73 kB)
#      ---------------------------------------- 73.7/73.7 kB 4.0 MB/s eta 0:00:00
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#      -------------------------------------- 122.8/122.8 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=Y,y=y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Model Error")
plt.show()
