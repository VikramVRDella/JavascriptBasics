# %%
import pandas as pd

# %%
employee_data=pd.read_csv("employee_data.csv")

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %%
#read_csv : you can't import multiple sheets using this function, you need to have seperate csv file
#read_excel: you can import multiple sheets using this function

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel("Project-Management-Sample-Data.xlsx")
# Out:
#     Unnamed: 0               Unnamed: 1               Unnamed: 2   Unnamed: 3  \
# 0          NaN        Excel Sample Data                      NaN          NaN
# 1          NaN                      NaN                      NaN          NaN
# 2          NaN  Project Management Data                      NaN          NaN
# 3          NaN                      NaN                      NaN          NaN
# 4          NaN             Project Name                Task Name  Assigned to
# 5          NaN                Marketing          Market Research        Alice
# 6          NaN                Marketing         Content Creation          Bob
# 7          NaN                Marketing    Social Media Planning      Charlie
# 8          NaN                Marketing        Campaign Analysis        Daisy
# 9          NaN              Product Dev    Prototype Development        Ethan
# 10         NaN              Product Dev        Quality Assurance        Fiona
# ...

# %%
employee_data=pd.read_csv("employee_data.csv")

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %%
employee_data.drop_duplicates(inplace=True)

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
employee_data.isna().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %%
employee_data["Department"].unique()
# Out:
# array(['Ops', 'IT Tech', 'Support', 'IT'], dtype=object)

# %%
employee_data[employee_data["Department"] == "Support"]
# Out:
#       Name   Age Department   Salary   Join_Date
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data[employee_data["Department"] == "IT Tech"]
# Out:
#     Name   Age Department  Salary   Join_Date
# 1  Nasir  31.0    IT Tech     NaN  12-11-2020

# %%
employee_data[employee_data["Department"] == "Ops"]
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021

# %%
employee_data[employee_data["Department"] == "IT"]
# Out:
#   Name   Age Department   Salary   Join_Date
# 6  NaN  40.0         IT  64000.0  10-09-2022

# %%
filter_data=employee_data[(employee_data["Department"] == "IT Tech") & (employee_data["Salary"].isna())]
