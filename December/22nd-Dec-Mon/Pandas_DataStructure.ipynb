# %% [markdown]
# ### Pandas Data Structure

# %%
import pandas as pd

# %% [markdown]
# #### Data Structure
# - Series    - 1 Dimensional
# - DataFrame - 2 Dimensional

# %%
pd.Series(data=[1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.DataFrame(data=[1,2,3,4])
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
marks = pd.DataFrame({"Name":["Hendry","Mathew"],"Maths":[79,80],"science":[80,81]})

# %%
marks
# Out:
#      Name  Maths  science
# 0  Hendry     79       80
# 1  Mathew     80       81
