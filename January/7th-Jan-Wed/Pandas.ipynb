# %%
import pandas as pd

# %%
enterprise = pd.read_csv('annual.csv')
enterprise
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
enterprise.shape
# Out:
# (55620, 10)

# %%
enterprise.size
# Out:
# 556200

# %%
enterprise.isna().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
enterprise.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
anual = enterprise['Value']

# %%
anual
# Out:
# 0        979594
# 1        838626
# 2        112188
# 3         28781
# 4        856960
#           ...
# 55615        52
# 55616        40
# 55617        12
# 55618         5
# 55619        46
# Name: Value, Length: 55620, dtype: object

# %%
anual.isna().sum()
# Out:
# np.int64(0)

# %%
enterprise
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
dataset=enterprise[['Year','Units','Variable_category','Variable_name','Value']]

# %%
dataset
# Out:
#        Year               Units      Variable_category  \
# 0      2024  Dollars (millions)  Financial performance
# 1      2024  Dollars (millions)  Financial performance
# 2      2024  Dollars (millions)  Financial performance
# 3      2024  Dollars (millions)  Financial performance
# 4      2024  Dollars (millions)  Financial performance
# ...     ...                 ...                    ...
# 55615  2013          Percentage       Financial ratios
# 55616  2013          Percentage       Financial ratios
# 55617  2013          Percentage       Financial ratios
# 55618  2013          Percentage       Financial ratios
# 55619  2013          Percentage       Financial ratios
#
#                                          Variable_name   Value
# 0                                         Total income  979594
# 1      Sales, government funding, grants and subsidies  838626
# 2                    Interest, dividends and donations  112188
# ...

# %%
dataset['Value'] = pd.to_numeric(dataset['Value'],errors='coerce')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_110048\2708167761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Value'] = pd.to_numeric(dataset['Value'],errors='coerce')

# %%
dataset.dtypes
# Out:
# Year                   int64
# Units                 object
# Variable_category     object
# Variable_name         object
# Value                float64
# dtype: object

# %%
dataset
# Out:
#        Year               Units      Variable_category  \
# 0      2024  Dollars (millions)  Financial performance
# 1      2024  Dollars (millions)  Financial performance
# 2      2024  Dollars (millions)  Financial performance
# 3      2024  Dollars (millions)  Financial performance
# 4      2024  Dollars (millions)  Financial performance
# ...     ...                 ...                    ...
# 55615  2013          Percentage       Financial ratios
# 55616  2013          Percentage       Financial ratios
# 55617  2013          Percentage       Financial ratios
# 55618  2013          Percentage       Financial ratios
# 55619  2013          Percentage       Financial ratios
#
#                                          Variable_name     Value
# 0                                         Total income  979594.0
# 1      Sales, government funding, grants and subsidies  838626.0
# 2                    Interest, dividends and donations  112188.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
year=dataset['Year']
salary=dataset['Value']

# %%
plt.scatter(x=year,y=salary)
plt.xlabel("Year")
plt.ylabel("Salary")
plt.show()

# %%
dataset.shape
# Out:
# (55620, 5)

# %%
dataset.head()
# Out:
#    Year               Units      Variable_category  \
# 0  2024  Dollars (millions)  Financial performance
# 1  2024  Dollars (millions)  Financial performance
# 2  2024  Dollars (millions)  Financial performance
# 3  2024  Dollars (millions)  Financial performance
# 4  2024  Dollars (millions)  Financial performance
#
#                                      Variable_name     Value
# 0                                     Total income  979594.0
# 1  Sales, government funding, grants and subsidies  838626.0
# 2                Interest, dividends and donations  112188.0
# 3                             Non-operating income   28781.0
# 4                                Total expenditure  856960.0

# %%
dataset.tail()
# Out:
#        Year       Units Variable_category  \
# 55615  2013  Percentage  Financial ratios
# 55616  2013  Percentage  Financial ratios
# 55617  2013  Percentage  Financial ratios
# 55618  2013  Percentage  Financial ratios
# 55619  2013  Percentage  Financial ratios
#
#                              Variable_name  Value
# 55615                          Quick ratio   52.0
# 55616  Margin on sales of goods for resale   40.0
# 55617                     Return on equity   12.0
# 55618               Return on total assets    5.0
# 55619                Liabilities structure   46.0
