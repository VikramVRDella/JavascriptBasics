# %% [markdown]
# ### Core Learning Algorithms
# * Linear Regression
# * Classification
# * Clustering
# * Hidden Markov Models

# %% [markdown]
# #### Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]

plt.plot(x,y, 'ro')
plt.show()

# %%
titanic_dataset = pd.read_csv('titanic.csv')

# %%
titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_survived = titanic_dataset[['Pclass','Survived','Sex','Age']]

# %%
titanic_survived
# Out:
#      Pclass  Survived     Sex   Age
# 0         3         0    male  22.0
# 1         1         1  female  38.0
# 2         3         1  female  26.0
# 3         1         1  female  35.0
# 4         3         0    male  35.0
# ..      ...       ...     ...   ...
# 886       2         0    male  27.0
# 887       1         1  female  19.0
# 888       3         0  female   NaN
# 889       1         1    male  26.0
# 890       3         0    male  32.0
#
# [891 rows x 4 columns]
